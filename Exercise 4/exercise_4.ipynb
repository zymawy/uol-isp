# %%
# !pip install deepspeech
# !pip install numpy
# !pip install scipy
# !pip install sox
# !pip install pydub
# Out:
# ERROR: Could not find a version that satisfies the requirement deepspeech (from versions: none)
# ERROR: No matching distribution found for deepspeech
# Requirement already satisfied: numpy in /Users/zymawy/Code/l6/awd/mid/midterm/.venv/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: scipy in /Users/zymawy/Code/l6/awd/mid/midterm/.venv/lib/python3.11/site-packages (1.13.0)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /Users/zymawy/Code/l6/awd/mid/midterm/.venv/lib/python3.11/site-packages (from scipy) (1.26.4)
# Requirement already satisfied: sox in /Users/zymawy/Code/l6/awd/mid/midterm/.venv/lib/python3.11/site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.9.0 in /Users/zymawy/Code/l6/awd/mid/midterm/.venv/lib/python3.11/site-packages (from sox) (1.26.4)
# Requirement already satisfied: typing-extensions>=3.7.4.2 in /Users/zymawy/Code/l6/awd/mid/midterm/.venv/lib/python3.11/site-packages (from sox) (4.11.0)
# Requirement already satisfied: pydub in /Users/zymawy/Code/l6/awd/mid/midterm/.venv/lib/python3.11/site-packages (0.25.1)

# %% [markdown]
# ### Preprocess Audio Files

# %%
from pydub import AudioSegment
from pydub.effects import normalize

def preprocess_audio(file_path):
    audio = AudioSegment.from_wav(file_path)
    normalized_audio = normalize(audio)
    processed_file_path = file_path.replace(".wav", "_processed.wav")
    normalized_audio.export(processed_file_path, format="wav")
    return processed_file_path
